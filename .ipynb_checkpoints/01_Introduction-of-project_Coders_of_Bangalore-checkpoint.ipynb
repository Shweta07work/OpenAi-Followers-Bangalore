# %% [markdown]
# ## Coders of Bangalore:
#
# ## Introduction
#
# In this project, I am analyzing raw Instagram data of OpenAI followers to understand their activity, audience, and account categories.
#
# The analysis focuses on identifying users with the **maximum posts, followers, and following**, along with the number of different account categories and users in each category.
#
# The main goal is to explore the data, extract meaningful insights, and answer the given business questions using **Python**.
